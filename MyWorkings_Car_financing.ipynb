# %%
import pandas as pd
xx='/Users/thamc/OneDrive/Desktop/RISE BCG/Classes/Python/3_Pandas/data/car_financing.csv'
df=pd.read_csv(xx)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-caa70c34c1de> in <module>
#       1 import pandas as pd
#       2 xx='/Users/thamc/OneDrive/Desktop/RISE BCG/Classes/Python/3_Pandas/data/car_financing.csv'
# ----> 3 df=pd.read_csv(xx)
#       4 df
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             408 non-null    int64
#  1   Starting Balance  408 non-null    float64
#  2   Repayment         408 non-null    float64
#  3   Interest Paid     408 non-null    float64
#  4   Principal Paid    408 non-null    float64
#  5   New Balance       408 non-null    float64
#  6   term              408 non-null    int64
#  7   interest_rate     408 non-null    float64
#  8   car_type          408 non-null    object
# dtypes: float64(6), int64(2), object(1)
# memory usage: 28.8+ KB

# %%
df.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna

# %%
df[['car_type', 'Repayment']]
# Out:
#           car_type  Repayment
# 0    Toyota Sienna     687.23
# 1    Toyota Sienna     687.23
# 2    Toyota Sienna     687.23
# 3    Toyota Sienna     687.23
# 4    Toyota Sienna     687.23
# ..             ...        ...
# 403      VW Golf R     796.01
# 404      VW Golf R     796.01
# 405      VW Golf R     796.01
# 406      VW Golf R     796.01
# 407      VW Golf R     796.01
#
# [408 rows x 2 columns]

# %%
df[9:21]
# Out:
#     Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 9      10          30227.88     687.23         176.83          510.40
# 10     11          29717.48     687.23         173.84          513.39
# 11     12          29204.09     687.23         170.84          516.39
# 12     13          28687.70     687.23         167.82          519.41
# 13     14          28168.29     687.23         164.78          522.45
# 14     15          27645.84     687.23         161.72          525.51
# 15     16          27120.33     687.23         158.65          528.58
# 16     17          26591.75     687.23         155.56          531.67
# 17     18          26060.08     687.23         152.45          534.78
# 18     19          25525.30     687.23         149.32          537.91
# 19     20          24987.39     687.23         146.17          541.06
# 20     21          24446.33     687.23         143.01          544.22
#
#     New Balance  term  interest_rate       car_type
# ...

# %%
df.loc[:, 'Repayment'].head()
# Out:
# 0    687.23
# 1    687.23
# 2    687.23
# 3    687.23
# 4    687.23
# Name: Repayment, dtype: float64

# %%
df.loc[:, ['Repayment', 'car_type', 'term']]
# Out:
#      Repayment       car_type  term
# 0       687.23  Toyota Sienna    60
# 1       687.23  Toyota Sienna    60
# 2       687.23  Toyota Sienna    60
# 3       687.23  Toyota Sienna    60
# 4       687.23  Toyota Sienna    60
# ..         ...            ...   ...
# 403     796.01      VW Golf R    60
# 404     796.01      VW Golf R    60
# 405     796.01      VW Golf R    60
# 406     796.01      VW Golf R    60
# 407     796.01      VW Golf R    60
#
# [408 rows x 3 columns]

# %%
df['car_type'].value_counts()
# Out:
# VW Golf R         144
# Toyota Sienna     120
# Toyota Carolla    111
# Toyota Corolla     33
# Name: car_type, dtype: int64

# %%
df['term'].value_counts()
# Out:
# 60    240
# 48     96
# 36     72
# Name: term, dtype: int64

# %%
filter=df['car_type']=='Toyota Sienna'
filter
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 403    False
# 404    False
# 405    False
# 406    False
# 407    False
# Name: car_type, Length: 408, dtype: bool

# %%
filter.head()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: Repayment, dtype: bool

# %%
filter=df['term'] < 60
filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 403    False
# 404    False
# 405    False
# 406    False
# 407    False
# Name: term, Length: 408, dtype: bool

# %%
import pandas as pd

# %%
import pandas as pd
xx='/Users/thamc/OneDrive/Desktop/RISE BCG/Classes/Python/3_Pandas/data/car_financing.csv'
df=pd.read_csv(xx)
df
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0        1          34689.96     687.23         202.93          484.30
# 1        2          34205.66     687.23         200.10          487.13
# 2        3          33718.53     687.23         197.25          489.98
# 3        4          33228.55     687.23         194.38          492.85
# 4        5          32735.70     687.23         191.50          495.73
# ..     ...               ...        ...            ...             ...
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate       car_type
# 0       34205.66    60         0.0702  Toyota Sienna
# ...

# %%
df['interest_rate']==0.072
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 403    False
# 404    False
# 405    False
# 406    False
# 407    False
# Name: interest_rate, Length: 408, dtype: bool

# %%
df['New Balance']>30000
df[0:20]
# Out:
#     Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0       1          34689.96     687.23         202.93          484.30
# 1       2          34205.66     687.23         200.10          487.13
# 2       3          33718.53     687.23         197.25          489.98
# 3       4          33228.55     687.23         194.38          492.85
# 4       5          32735.70     687.23         191.50          495.73
# 5       6          32239.97     687.23         188.60          498.63
# 6       7          31741.34     687.23         185.68          501.55
# 7       8          31239.79     687.23         182.75          504.48
# 8       9          30735.31     687.23         179.80          507.43
# 9      10          30227.88     687.23         176.83          510.40
# 10     11          29717.48     687.23         173.84          513.39
# 11     12          29204.09     687.23         170.84          516.39
# ...

# %%
import pandas as pd
x='/Users/thamc/OneDrive/Desktop/RISE BCG/Classes/Python/3_Pandas/data/car_financing.csv'
df=pd.read_csv(x)
df
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0        1          34689.96     687.23         202.93          484.30
# 1        2          34205.66     687.23         200.10          487.13
# 2        3          33718.53     687.23         197.25          489.98
# 3        4          33228.55     687.23         194.38          492.85
# 4        5          32735.70     687.23         191.50          495.73
# ..     ...               ...        ...            ...             ...
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate       car_type
# 0       34205.66    60         0.0702  Toyota Sienna
# ...

# %% [markdown]
# ## Self created table below

# %%
carloans=[['john', 2222, 3333, 1, 'h@gmail'],['leo', 44444, 55.55, 2, 'n@gmail'],['mary', 6666,7777],['nic', 777, 8.88, 3,'z@gmail'],['dean', 213, 33.22, 4, 'd@gmail']]
colnames=['Clients', 'Repayment', 'Interest Paid', 'Month', 'Email']
df=pd.DataFrame(data=carloans, columns=colnames)
df
# Out:
#   Clients  Repayment  Interest Paid  Month    Email
# 0    john       2222        3333.00    1.0  h@gmail
# 1     leo      44444          55.55    2.0  n@gmail
# 2    mary       6666        7777.00    NaN     None
# 3     nic        777           8.88    3.0  z@gmail
# 4    dean        213          33.22    4.0  d@gmail

# %% [markdown]
# ## If want to see just nic & dean records, 3/4 means starting from No.3 up till da total fourth row, hence only nic will appear

# %%
df[['Clients', 'Repayment']][3:4]
# Out:
#   Clients  Repayment
# 3     nic        777

# %% [markdown]
# ## Alternative to slicing using da loc fn, 0/2 means starting from No.0 to 2, count sequence is diff from above

# %%
df.loc[0:2, ['Clients', 'Repayment']]
# Out:
#   Clients  Repayment
# 0    john       2222
# 1     leo      44444
# 2    mary       6666

# %%
df.loc[1:3, ['Clients', 'Interest Paid']]
# Out:
#   Clients  Interest Paid
# 1     leo          55.55
# 2    mary        7777.00
# 3     nic           8.88

# %% [markdown]
# ### If wana see ALL da rows of any columns, just insert Colon will do

# %%
df.loc[:, ['Clients', 'Repayment']]
# Out:
#   Clients  Repayment
# 0    john       2222
# 1     leo      44444
# 2    mary       6666
# 3     nic        777
# 4    dean        213

# %%
df['Clients'].value_counts()
# Out:
# nic     1
# dean    1
# leo     1
# mary    1
# john    1
# Name: Clients, dtype: int64

# %%
filter=df['Repayment']>1000
filter
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: Repayment, dtype: bool

# %%
filter.value_counts()
# Out:
# True     3
# False    2
# Name: Repayment, dtype: int64

# %% [markdown]
# ## After filtering for ans above, below is to show which rows are TRUE

# %%
df[filter]
# Out:
#   Clients  Repayment  Interest Paid  Month    Email
# 0    john       2222        3333.00    1.0  h@gmail
# 1     leo      44444          55.55    2.0  n@gmail
# 2    mary       6666        7777.00    NaN     None
